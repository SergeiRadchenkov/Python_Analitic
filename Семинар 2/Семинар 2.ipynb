# %%
# Чтение и запись файлов
# csv #- comma-separated values - данные разделенные запятой
# df = pd.read_csv('file.csv', # функция считывания внешнего файла формата csv (можно выбрать необходимый формат)
# encoding='windows-1251',
# headler=0, # - какую строку считать заголовком(по умолчанию нулевую)
# sep = ';',
# index_col='название_столбца',
# parse_dates=['Date'],
# dayfirst=True)
# 'file.csv' - путь к файлу,
# sep - разделитель sep(по умолчаниию ',')
# encoding – параметр в read_csv, отвечает за кодировку текста, которая может быть различной. Самая распространённая – utf
# index_col='название_столбца' - название столбца, который будет выступать как столбец индексов
# index_col=[0] - индекс столбца, который будет выступать как столбец индексов
# parse_dates – указывает, стоит ли воспринимать даты как даты (по умолчанию они воспринимаются пандасом как строки).
# пример pd.read_csv(path, parse_dates=['some_date', 'another_date'])
# Параметр с датами может принимать несколько значений:
# True – пытается перевести в дату первую колонку
# список колонок – parse_dates=['some_date', 'another_date']
# пытается перевести в дату указанные в списке колонки и столбцы create_data, payment_data
# будут обрабатываться как даты
# dayfirst=True - первое значение в дате это день или нет - True/False
# df['Date'].dt.day - номер дня недели в соответствии с данными в колонке с датами !!!!!
# df['Date'].dt.day_name() - название дня недели в соответствии с данными в колонке с датами
# df['Date'].dt.month - номер месяца в соответствии с данными в колонке с датами
# df['Date'].dt.month_name() - название месяца в соответствии с данными в колонке с датами

# %% [markdown]
# ## Задание 1.
# - Посмотреть на описание признаков и на их содержание_x000b__x000b_Для решения задач вам может понадобиться файл “Расшифровка таблиц” (Дополнительный материал)

# %% [markdown]
# 1. Скачать данные файл laptop_prices.csv (Дополнительный материал)

# %%
import pandas as pd

# %% [markdown]
# 2. Считать данные с помощью pandas

# %%
df = pd.read_csv("laptop_price.csv", encoding='windows-1251')

# %% [markdown]
# 3. Вывести на экран первые 5 строк

# %%
df.head(10)
# Out:
#    laptop_ID Company          Product   TypeName  Inches  \
# 0          1   Apple      MacBook Pro  Ultrabook    13.3
# 1          2   Apple      Macbook Air  Ultrabook    13.3
# 2          3      HP           250 G6   Notebook    15.6
# 3          4   Apple      MacBook Pro  Ultrabook    15.4
# 4          5   Apple      MacBook Pro  Ultrabook    13.3
# 5          6    Acer         Aspire 3   Notebook    15.6
# 6          7   Apple      MacBook Pro  Ultrabook    15.4
# 7          8   Apple      Macbook Air  Ultrabook    13.3
# 8          9    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9         10    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# ...

# %%
df.tail(10)
# Out:
#       laptop_ID Company                                    Product  \
# 1293       1311  Lenovo                         IdeaPad Y700-15ISK
# 1294       1312      HP                        Pavilion 15-AW003nv
# 1295       1313    Dell                              Inspiron 3567
# 1296       1314      HP                           Stream 11-Y000na
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       1316  Lenovo                             Yoga 500-14ISK
# 1299       1317  Lenovo                             Yoga 900-13ISK
# 1300       1318  Lenovo                         IdeaPad 100S-14IBR
# 1301       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 1293            Notebook    15.6                 IPS Panel Full HD 1920x1080
# ...

# %%
df.sample(10)
# Out:
#       laptop_ID Company                           Product  TypeName  Inches  \
# 1120       1135    Vero  V131 (X5-Z8350/4GB/32GB/FHD/W10)  Notebook    13.3
# 196         200   Razer                         Blade Pro    Gaming    17.3
# 773         782    Dell                     Inspiron 7567    Gaming    15.6
# 53           54      HP                       ProBook 430  Notebook    13.3
# 686         694      HP                            250 G6  Notebook    15.6
# 620         627      HP                       ProBook 650  Notebook    14.0
# 835         844    Dell                      Alienware 15    Gaming    15.6
# 251         256    Asus                ROG G752VSK-GC493T    Gaming    17.3
# 284         289    Acer                   Aspire A517-51G  Notebook    15.6
# 378         384    Asus                   VivoBook E403NA  Notebook    14.0
#
#                          ScreenResolution  \
# 1120                    Full HD 1920x1080
# 196   4K Ultra HD / Touchscreen 3840x2160
# ...

# %% [markdown]
# ## Задание 2.
# Проведите первичный анализ данных

# %% [markdown]
# 1. Изучите типы данных

# %%
df.dtypes
# Out:
# laptop_ID             int64
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.isna().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# 2. Найдите количество пропущенных ячеек в данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %% [markdown]
# 3. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.describe(include = ['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %% [markdown]
# ## Задание 3.
# Ответьте на несколько вопросов

# %% [markdown]
# 1. Ноутбуков от какой компании больше всего в наборе данных?

# %%
company = df['Company'].value_counts().reset_index()
company
# Out:
#       Company  count
# 0        Dell    297
# 1      Lenovo    297
# 2          HP    274
# 3        Asus    158
# 4        Acer    103
# 5         MSI     54
# 6     Toshiba     48
# 7       Apple     21
# 8     Samsung      9
# 9       Razer      7
# 10   Mediacom      7
# 11  Microsoft      6
# 12     Xiaomi      4
# 13       Vero      4
# 14      Chuwi      3
# 15     Google      3
# 16    Fujitsu      3
# 17         LG      3
# 18     Huawei      2

# %%
company[company['count'] == 297]
# Out:
#   Company  count
# 0    Dell    297
# 1  Lenovo    297

# %%
company = df['Company'].value_counts()
company
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
company[company.values == 297]
# Out:
# Company
# Dell      297
# Lenovo    297
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# 2. Какая минимальная и максимальная стоимость у ноутбуков в данных?

# %%
df['Price_euros'].min(), df['Price_euros'].max()
# Out:
# (174.0, 6099.0)

# %% [markdown]
# 3. Какой самый дорогой ноутбук в данных?
# Выведите все характеристики только по этому ноутбуку.
# Если таких ноутбуков несколько, то выводите их всех.

# %%
df[df['Price_euros'] == df['Price_euros'].max()]
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %%
df.sort_values('Price_euros', ascending=False).iloc[0:3]
# Out:
#      laptop_ID Company       Product  TypeName  Inches  \
# 196        200   Razer     Blade Pro    Gaming    17.3
# 830        839   Razer     Blade Pro    Gaming    17.3
# 610        617  Lenovo  Thinkpad P51  Notebook    15.6
#
#                         ScreenResolution                            Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz  32GB
# 830  4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz  32GB
# 610      IPS Panel 4K Ultra HD 3840x2160  Intel Xeon E3-1535M v6 3.1GHz  32GB
#
#         Memory                      Gpu       OpSys  Weight  Price_euros
# 196    1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0
# 830  512GB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       5499.0
# 610    1TB SSD     Nvidia Quadro M2200M  Windows 10   2.5kg       4899.0

# %% [markdown]
# ## Задание 4.
# Ответьте на несколько вопросов
# 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %% [markdown]
# 1. Найдите ноутбуки с самой маленькой диагональю в данных?
# <br>Выведите только следующие характеристики:
# - Компания
# - Типа ноутбука
# - Диагональ
# - Стоимость <br> Если таких ноутбуков несколько, то выводите их всех

# %%
df[df['Inches'] == df['Inches'].min()][['Company', 'TypeName', 'Inches', 'Price_euros']]
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %% [markdown]
# 2. Сколько стоит самый дорогой ноутбук у компании HP?

# %%
df[df['Company'] == 'HP']['Price_euros'].max()
# Out:
# 4389.0

# %%
HP = df[df['Company'] == 'HP']
HP
HP[HP['Price_euros'] == HP['Price_euros'].max()]
# Out:
#      laptop_ID Company   Product     TypeName  Inches  \
# 749        758      HP  Zbook 17  Workstation    17.3
#
#                 ScreenResolution                            Cpu   Ram  \
# 749  IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz  16GB
#
#         Memory                   Gpu      OpSys Weight  Price_euros
# 749  256GB SSD  Nvidia Quadro M2000M  Windows 7    3kg       4389.0

# %% [markdown]
# 3. Как много ноутбуков Ultrabook с 8GB RAM? <br>Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %%
Ultra = df[df['TypeName'] == 'Ultrabook']
Ultra.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
# 6          7   Apple  MacBook Pro  Ultrabook    15.4
#
#                      ScreenResolution                   Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz   8GB
# 1                            1440x900  Intel Core i5 1.8GHz   8GB
# 3  IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
# 6  IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
#
#                 Memory                           Gpu     OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640     macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000     macOS  1.34kg
# ...

# %%
U8GB = Ultra[Ultra['Ram'] == '8GB']
count_U8GB = U8GB.shape[0]
count_U8GB
# Out:
# 140

# %%
count_u = Ultra.shape[0]
count_u
# Out:
# 196

# %%
round(count_U8GB / count_u * 100,2)
# Out:
# 71.43

# %%
Ultra.value_counts('Ram', normalize=True).round(4).loc['8GB']*100
# Out:
# 71.43

# %% [markdown]
# ## Задание 5.
# 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %% [markdown]
# 1. Выберите ноутбук клиенту<br>Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?

# %%
df[(df['Ram'] == '8GB') | (df['Ram'] == '16GB') ]
# Out:
#       laptop_ID Company               Product            TypeName  Inches  \
# 0             1   Apple           MacBook Pro           Ultrabook    13.3
# 1             2   Apple           Macbook Air           Ultrabook    13.3
# 2             3      HP                250 G6            Notebook    15.6
# 3             4   Apple           MacBook Pro           Ultrabook    15.4
# 4             5   Apple           MacBook Pro           Ultrabook    13.3
# ...         ...     ...                   ...                 ...     ...
# 1285       1303  Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1289       1307    Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1293       1311  Lenovo    IdeaPad Y700-15ISK            Notebook    15.6
# 1295       1313    Dell         Inspiron 3567            Notebook    15.6
# 1299       1317  Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# ...

# %%
df[(df['Ram'].isin(['8GB', '16'])) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] < 500)].shape[0]
# Out:
# 13

# %% [markdown]
# 2. Выберите ноутбук клиенту
# <br>Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. <br>В какой ценовой категории вышли подобные ноутбуки?

# %%
msi = df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & (df['Inches'] != 15.6)]
msi
# Out:
#       laptop_ID Company        Product TypeName  Inches   ScreenResolution  \
# 330         336     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393         400     MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 724         732     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917         931     MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
# 1156       1174     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# ...

# %%
msi['Price_euros'].min(), msi['Price_euros'].max()
# Out:
# (1199.0, 1599.0)

# %% [markdown]
# 3. Что дешевле?
# <br>В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean().round(2)
# Out:
# 1760.41

# %%
df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean().round(2)
# Out:
# 1915.71

# %% [markdown]
# ## Задание 6. Найдите самый легкий ноутбук

# %% [markdown]
# Найдите самый легкий ноутбук<br>
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
df['Weight'] = df['Weight'].str.replace('kg', '').astype('float')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# ...

# %%
df[df['Weight'] == df['Weight'].min()]
# Out:
#       laptop_ID Company    Product            TypeName  Inches  \
# 50           51  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1082       1097  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1114       1129  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1126       1141  Lenovo  Yoga Book  2 in 1 Convertible    10.1
#
#                      ScreenResolution                          Cpu  Ram  \
# 50    IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1082  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1114  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1126  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 50    64GB Flash Storage  Intel HD Graphics 400     Android    0.69
# 1082  64GB Flash Storage  Intel HD Graphics 400  Windows 10    0.69
# 1114  64GB Flash Storage  Intel HD Graphics 400     Android    0.69
# ...
